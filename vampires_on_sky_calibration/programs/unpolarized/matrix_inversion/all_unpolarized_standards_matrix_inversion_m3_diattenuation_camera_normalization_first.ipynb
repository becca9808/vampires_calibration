# %%
import os
import sys
py_files_dir = os.path.abspath("../../py_files/")
sys.path.insert(0, py_files_dir)

import matplotlib.pyplot as plt
import itertools
import helper_functions as funcs
import instrument_matrices as matrices
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import scipy_minimize_m3 as m3

# %%
import os
import shutil

def copy_files(file_list, dest_dir):
    """
    Copies files from their source paths to the destination directory, allowing overwrite.

    Args:
        file_list (list): List of full file paths to copy.
        dest_dir (str): Destination directory path.

    Returns:
        None
    """
    # Ensure destination directory exists
    os.makedirs(dest_dir, exist_ok=True)

    for src_file in file_list:
        file_name = os.path.basename(src_file)
        dest_file = os.path.join(dest_dir, file_name)

        try:
            shutil.copy2(src_file, dest_file)
            print(f"Copied {src_file} to {dest_file}")
        except FileNotFoundError:
            print(f"File not found: {src_file}")
        except Exception as e:
            print(f"Error copying {src_file} to {dest_file}: {e}")

# Example usage
file_list = [
    "/home/shared/exoserver/VAMPIRES/20220127/HD108767_01292022_Dark_Subtracted/rz_dpp/collapsed/20240111_HD108767_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv",
    "/home/shared/exoserver/VAMPIRES/20220127/HD36819/rz_dpp/675/analysis/20240109_HD36819_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv",
    "/home/shared/exoserver/VAMPIRES/20220127/eta_crv/rz_dpp/collapsed/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv",
    "/home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD128750/norm_675nm_em15/collapsed/20240122_HD128750_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv",
    "/home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD173667/norm_675_em1/collapsed/20240131_HD173667_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv",
    "/home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD173667/norm_675_em5/collapsed/20240201_HD173667_em5_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv"
]

dest_dir = '../../../data/unpolarized/csv'  # Relative destination directory

copy_files(file_list, dest_dir)
# Out:
# Copied /home/shared/exoserver/VAMPIRES/20220127/HD108767_01292022_Dark_Subtracted/rz_dpp/collapsed/20240111_HD108767_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240111_HD108767_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv
# Copied /home/shared/exoserver/VAMPIRES/20220127/HD36819/rz_dpp/675/analysis/20240109_HD36819_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240109_HD36819_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv
# Copied /home/shared/exoserver/VAMPIRES/20220127/eta_crv/rz_dpp/collapsed/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv
# Copied /home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD128750/norm_675nm_em15/collapsed/20240122_HD128750_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240122_HD128750_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv
# Copied /home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD173667/norm_675_em1/collapsed/20240131_HD173667_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240131_HD173667_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv
# Copied /home/shared/exoserver/Subaru/Vampires/Raw/20210714/HD173667/norm_675_em5/collapsed/20240201_HD173667_em5_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv to ../../../data/unpolarized/csv/20240201_HD173667_em5_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv

# %% [markdown]
# # Setting Up Initial Instrument Parameters

# %%
# Internal Calibration Model Parameters from MCMC best fit value - 
# https://docs.google.com/spreadsheets/d/1i8TjHzQFMmxaUWrrqm1eYziyUanC6pweGGFzJPdfbiE/edit#gid=0

delta_m3 = 0 # (waves) - assumed to be zero for now
epsilon_m3 = 0  # Rough value from unpolarized standards fit
offset_m3 = 0  # NOTE: Made this zero too for testing purposes
em_gain = 0.423  # Add your actual em_gain value
delta_HWP = 0.451  # Add your actual delta_HWP value
offset_HWP = -2.642  # Add your actual offset_HWP value
delta_derot = 0.32  # Add your actual delta_derot value
offset_derot = -0.011  # Add your actual offset_derot value
delta_opts = -0.163  # Add your actual delta_opts value
epsilon_opts = 0.036  # Add your actual epsilon_opts value
rot_opts = -7.151  # Add your actual rot_opts value
delta_FLC = 0.302  # Add your actual delta_FLC value
rot_FLC = 0.256  # Add your actual rot_FLC value

# Having no EM gain difference in the Mueller matrix model
# delta_FLC = 0.5
em_gain = 1
# epsilon_opts = 0 # Made this zero for testing purposes

# For figuring out the correrct factor for the double diff matrix
double_diff_factor = 1

fixed_params = [delta_m3, epsilon_m3, offset_m3, delta_HWP, offset_HWP, 
    delta_derot, offset_derot, delta_opts, epsilon_opts, rot_opts, delta_FLC, 
    rot_FLC, em_gain]

# %% [markdown]
# # Load .csv files

# %%
csv_directory = '../../../data/unpolarized/csv'
csv_files = funcs.load_all_files_from_directory(csv_directory, ".csv")

# Load data from all CSV files
all_data = pd.DataFrame()
for file in csv_files:
    df = pd.read_csv(file)
    df_filtered = df[(df['Q'] != 0) | (df['U'] != 0)]
    all_data = pd.concat([all_data, df])

all_data.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Plotting the Data in the HWP angle frame

# %%
# Extract unique objects and generate colors
unique_objects = all_data['OBJECT'].unique()
colors = itertools.cycle(plt.cm.tab10.colors)  # Use a colormap with a cycle of 10 colors

double_diff_string = "EM_GAIN_ADJUSTED_UNNORAMALIZED_DOUBLE_DIFFS"

# Initialize lists for storing the results
wavelength = 675
Q_list = []
U_list = []
Q_err_list = []
U_err_list = []
final_altitudes = []

model = matrices.full_system_mueller_matrix

# Loop through each unique object
for obj in unique_objects:
    object_data = all_data[all_data['OBJECT'] == obj]
    color = next(colors)

    # Initialize lists for this object
    first_rows = []
    inst_matrices_at_HWP = []
    this_cycle_intensities = []
    this_cycle_altitudes = []
    this_cycle_errors = []

    for i, row in object_data.iterrows():
        HWP_ang = row["U_HWPANG"]
        IMR_ang = row["D_IMRANG"]
        cam_num = row["U_CAMERA"]
        FLC_state = row["U_FLCSTT"]
        altitude = row["ALTITUDE"]
        data_Q = row["Q"]
        print("HWP_ang: " + str(HWP_ang))
        print("IMR_ang: " + str(IMR_ang))
        print("Altitude: " + str(altitude))

        # NOTE: This is for normalized differences
        double_difference = row[double_diff_string]
        # double_sum = row["DOUBLE_SUM"]
        double_difference_err = row["DOUBLE_DIFFERENCE_ERRS"]

        if double_difference != 0:
            # Append intensities and altitudes for this cycle
            this_cycle_intensities.append(double_difference)
            this_cycle_altitudes.append(altitude)
            this_cycle_errors.append(double_difference_err)

            # Calculate instrument matrix at HWP
            these_inst_matrices_at_HWP = matrices.full_system_mueller_matrix_normalized_double_diff_and_sum(
                model, fixed_params, 0, 0, HWP_ang, IMR_ang, factor = double_diff_factor)
            double_diff_matrix_at_HWP = these_inst_matrices_at_HWP[0]
            double_sum_matrix_at_HWP = these_inst_matrices_at_HWP[1]

            # Setting the I component to be 1
            double_diff_matrix_at_HWP[0, 0] = 1

            # Saving instrument matrices
            inst_matrices_at_HWP.append(double_diff_matrix_at_HWP)
            inst_matrices_at_HWP.append(double_sum_matrix_at_HWP)

            # Take only the first row and I, Q, U, components (no V)
            first_rows.append(double_diff_matrix_at_HWP[0, : 3])  

        # Do one inversion for one HWP cycle
        if data_Q != 0:
            # Constructing measurement matrix to reconstruct Stokes vector at HWP
            measurement_matrix = np.vstack(first_rows)
            print("Measurement Matrix: " + str(measurement_matrix))

            measurements = np.array(this_cycle_intensities).reshape(-1, 1)  # Reshape total counts to a column vector
            errors = np.array(this_cycle_errors).reshape(-1, 1)  # Reshape errors to a column vector

            # Compute the pseudo-inverse of the measurement matrix and multiply it by the measurements vector
            s_HWP = np.linalg.pinv(measurement_matrix) @ measurements

            # Compute the errors for the Stokes parameters
            s_HWP_err = np.linalg.pinv(measurement_matrix) @ errors

            # Extract Q and U from s_HWP and their errors
            Q = s_HWP[1]
            U = s_HWP[2]
            Q_err = s_HWP_err[1]
            U_err = s_HWP_err[2]

            # Append Q, U, altitude, and errors to the lists
            Q_list.append((altitude, Q, color, obj))
            U_list.append((altitude, U, color, obj))
            Q_err_list.append(Q_err)
            U_err_list.append(U_err)

            # Saving the mean of the altitudes
            mean_altitude = np.mean(this_cycle_altitudes)

            # Reset measurement matrix rows and double diff and sum measurements
            first_rows = []  
            this_cycle_intensities = []
            this_cycle_altitudes = []
            this_cycle_errors = []

            final_altitudes.append(mean_altitude)

# TODO: See if it's ok to just take the absolute uncertainties
Q_err_list = np.abs(Q_err_list)
U_err_list = np.abs(U_err_list)

# Plotting
plt.figure(figsize=(12, 8))
plotted_labels = set()
for (altitude, Q, color, obj), Q_err in zip(Q_list, Q_err_list):
    label = f'Q - {obj}' if f'Q - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, Q, yerr=Q_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor=color)
    plotted_labels.add(f'Q - {obj}')

for (altitude, U, color, obj), U_err in zip(U_list, U_err_list):
    label = f'U - {obj}' if f'U - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, U, yerr=U_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor='none', markeredgecolor=color)
    plotted_labels.add(f'U - {obj}')

# plt.title(f"Stokes Q and U of {wavelength}nm Eta Crv Data @ HWP - EM Gain Ratio = " + str(em_gain))
plt.xlabel("Altitude (Degrees)")
plt.ylabel("Stokes (Q/U)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Measurement Matrix: [[ 1.          1.07558696  0.05817318]
#  [ 1.         -1.13730124 -0.18239288]
#  [ 1.          0.12468107 -1.134011  ]
#  [ 1.         -0.23668498  1.12470293]]
# Measurement Matrix: [[ 1.          1.0759582   0.0682969 ]
#  [ 1.         -1.13592339 -0.19161986]
#  [ 1.          0.1363768  -1.13324771]
#  [ 1.         -0.24450812  1.12357224]]
# Measurement Matrix: [[ 1.          1.0762327   0.07855786]
#  [ 1.         -1.13450857 -0.20044053]
#  [ 1.          0.14622968 -1.13249696]
#  [ 1.         -0.25196615  1.12239432]]
# Measurement Matrix: [[ 1.          1.07640533  0.08884949]
#  [ 1.         -1.13289697 -0.20983373]
#  [ 1.          0.15548222 -1.13170225]
#  [ 1.         -0.25990642  1.12103299]]
# Measurement Matrix: [[ 1.          1.07647466  0.09881485]
#  [ 1.         -1.13128767 -0.21864026]
#  [ 1.          0.16628845 -1.1306641 ]
#  [ 1.         -0.26718104  1.11968873]]
# Measurement Matrix: [[ 1.          1.06728168  0.23894037]
#  [ 1.         -1.09902402 -0.34085677]
#  [ 1.          0.30187407 -1.10747923]
#  [ 1.         -0.37049864  1.09048463]]
# Measurement Matrix: [[ 1.          1.06582383  0.24944665]
#  [ 1.         -1.09589207 -0.34988479]
#  [ 1.          0.31202884 -1.1049731 ]
#  [ 1.         -0.37803407  1.08760137]]
# Measurement Matrix: [[ 1.          1.06430499  0.25964484]
#  [ 1.         -1.09263678 -0.3589609 ]
#  [ 1.          0.3219859  -1.10240917]
#  [ 1.         -0.3857339   1.08454636]]
# Measurement Matrix: [[ 1.          1.06267118  0.26991875]
#  [ 1.         -1.08929597 -0.3679781 ]
#  [ 1.          0.33182643 -1.09977093]
#  [ 1.         -0.39296656  1.08157578]]
# Measurement Matrix: [[ 1.          1.060948    0.28010589]
#  [ 1.         -1.08591716 -0.37681737]
#  [ 1.          0.34200576 -1.09693205]
#  [ 1.         -0.40068156  1.07829847]]
# Measurement Matrix: [[ 1.          1.02707279  0.4185121 ]
#  [ 1.         -1.02939513 -0.4967944 ]
#  [ 1.          0.47488392 -1.04920879]
#  [ 1.         -0.5012926   1.02475734]]
# Measurement Matrix: [[ 1.          1.02384502  0.42850729]
#  [ 1.         -1.02465188 -0.50519414]
#  [ 1.          0.48434532 -1.04501787]
#  [ 1.         -0.50848425  1.0201133 ]]
# Measurement Matrix: [[ 1.          1.0205889   0.43826237]
#  [ 1.         -1.0198051  -0.51358341]
#  [ 1.          0.49391408 -1.04066603]
#  [ 1.         -0.51549822  1.01547124]]
# Measurement Matrix: [[ 1.          1.01714269  0.44825882]
#  [ 1.         -1.01467318 -0.5222641 ]
#  [ 1.          0.5033317  -1.03627024]
#  [ 1.         -0.52273379  1.01056397]]
# Measurement Matrix: [[ 1.          1.01368624  0.45797376]
#  [ 1.         -1.00975941 -0.53039109]
#  [ 1.          0.5125949  -1.03183609]
#  [ 1.         -0.52957882  1.00580898]]
# Measurement Matrix: [[ 1.          0.71544799  0.89471408]
#  [ 1.         -0.63631471 -0.89159513]
#  [ 1.          0.91946373 -0.68786867]
#  [ 1.         -0.82153607  0.64714743]]
# Measurement Matrix: [[ 1.          0.7175061   0.89291702]
#  [ 1.         -0.64025778 -0.88931014]
#  [ 1.          0.91713425 -0.69111912]
#  [ 1.         -0.81981656  0.65086198]]
# Measurement Matrix: [[ 1.          0.9065857   0.67393933]
#  [ 1.         -0.87140665 -0.70862231]
#  [ 1.          0.70687765 -0.91038209]
#  [ 1.         -0.66999586  0.88015335]]
# Measurement Matrix: [[ 1.          0.91564831  0.65968166]
#  [ 1.         -0.88179843 -0.69773899]
#  [ 1.          0.69466993 -0.91982458]
#  [ 1.         -0.66131755  0.88973838]]
# Measurement Matrix: [[ 1.          1.07647673  0.1002637 ]
#  [ 1.         -1.13246318 -0.21225956]
#  [ 1.          0.15360623 -1.13187041]
#  [ 1.         -0.25320093  1.12218988]]
# Measurement Matrix: [[ 1.          1.07633498  0.08389085]
#  [ 1.         -1.13462482 -0.19973759]
#  [ 1.          0.13581463 -1.13328758]
#  [ 1.         -0.2394441   1.12431642]]
# Measurement Matrix: [[ 1.          0.87041099  0.72633167]
#  [ 1.         -0.82484685 -0.75382275]
#  [ 1.          0.75920158 -0.86656842]
#  [ 1.         -0.70928626  0.8329026 ]]
# Measurement Matrix: [[ 1.          0.87642062  0.71808243]
#  [ 1.         -0.83195109 -0.74727708]
#  [ 1.          0.75106422 -0.87375823]
#  [ 1.         -0.70352976  0.84025084]]
# Measurement Matrix: [[ 1.          0.88243436  0.70965633]
#  [ 1.         -0.8400835  -0.7396353 ]
#  [ 1.          0.74375118 -0.88009711]
#  [ 1.         -0.69771473  0.84751777]]
# Measurement Matrix: [[ 1.          0.96810385  0.56531251]
#  [ 1.         -0.94982029 -0.61773518]
#  [ 1.          0.60611609 -0.98057801]
#  [ 1.         -0.5965453   0.95309464]]
# Measurement Matrix: [[ 1.          0.97266258  0.55591263]
#  [ 1.         -0.9555938  -0.61012557]
#  [ 1.          0.59788843 -0.98558636]
#  [ 1.         -0.5899556   0.95881291]]
# Measurement Matrix: [[ 1.          0.97718087  0.54635662]
#  [ 1.         -0.96123666 -0.60254257]
#  [ 1.          0.58832908 -0.99127909]
#  [ 1.         -0.58258935  0.96506043]]
# Measurement Matrix: [[ 1.          0.82656869 -0.55704294]
#  [ 1.         -1.01344209  0.34341584]
#  [ 1.         -0.46417563 -0.96572055]
#  [ 1.          0.19647673  0.98372536]]
# Measurement Matrix: [[ 1.          0.84980561 -0.53084075]
#  [ 1.         -1.02483942  0.32815718]
#  [ 1.         -0.44648006 -0.97864415]
#  [ 1.          0.18418493  0.99587834]]
# Measurement Matrix: [[ 1.          0.86468771 -0.51291558]
#  [ 1.         -1.03561877  0.31269854]
#  [ 1.         -0.4287073  -0.99088467]
#  [ 1.          0.17178885  1.00729438]]
# Measurement Matrix: [[ 1.          0.87905647 -0.49467129]
#  [ 1.         -1.04573547  0.29715968]
#  [ 1.         -0.4107825  -1.00252843]
#  [ 1.          0.15890357  1.01834728]]
# Measurement Matrix: [[ 1.          0.89363363 -0.47512981]
#  [ 1.         -1.057801    0.2771198 ]
#  [ 1.         -0.38781976 -1.01648338]
#  [ 1.          0.14303118  1.03092439]]
# Measurement Matrix: [[ 1.          0.90940372 -0.45269002]
#  [ 1.         -1.06663145  0.26124253]
#  [ 1.         -0.3693273  -1.02698514]
#  [ 1.          0.12992592  1.04051715]]
# Measurement Matrix: [[ 1.          0.92377361 -0.4309252 ]
#  [ 1.         -1.07703923  0.24096465]
#  [ 1.         -0.34612262 -1.03929075]
#  [ 1.          0.11332143  1.05172768]]
# Measurement Matrix: [[ 1.          0.93640551 -0.41062317]
#  [ 1.         -1.08469717  0.22476101]
#  [ 1.         -0.32746281 -1.04851945]
#  [ 1.          0.10008251  1.05996405]]
# Measurement Matrix: [[ 1.          0.94776781 -0.39130909]
#  [ 1.         -1.09189687  0.20833534]
#  [ 1.         -0.30906715 -1.05706436]
#  [ 1.          0.08669191  1.06770317]]
# Measurement Matrix: [[ 1.          0.95814927 -0.3726826 ]
#  [ 1.         -1.09849285  0.19207494]
#  [ 1.         -0.2906825  -1.06507852]
#  [ 1.          0.07330402  1.07487945]]
# Measurement Matrix: [[ 1.          0.96808121 -0.35387691]
#  [ 1.         -1.10459385  0.17578764]
#  [ 1.         -0.2723702  -1.0725591 ]
#  [ 1.          0.0599489   1.08150836]]
# Measurement Matrix: [[ 1.          0.97728333 -0.33548189]
#  [ 1.         -1.11014992  0.15968145]
#  [ 1.         -0.25423116 -1.07949277]
#  [ 1.          0.04680676  1.08753997]]
# Measurement Matrix: [[ 1.          0.98596663 -0.31715266]
#  [ 1.         -1.11518348  0.14379458]
#  [ 1.         -0.23210139 -1.08733316]
#  [ 1.          0.03040959  1.09441456]]
# Measurement Matrix: [[ 1.          1.03144313 -0.19852091]
#  [ 1.         -1.13877766  0.0352165 ]
#  [ 1.         -0.11497375 -1.11839589]
#  [ 1.          1.05109072 -0.12544207]
#  [ 1.         -1.14446295 -0.02425689]
#  [ 1.         -0.04929038 -1.128766  ]
#  [ 1.         -0.10439796  1.12724512]]
# Measurement Matrix: [[ 1.          1.05427413 -0.1110147 ]
#  [ 1.         -1.14498058 -0.0349289 ]
#  [ 1.         -0.03764544 -1.1301089 ]
#  [ 1.         -0.1131107   1.12806956]]
# Measurement Matrix: [[ 1.          1.05669349 -0.09930937]
#  [ 1.         -1.14533388 -0.04505484]
#  [ 1.         -0.02641979 -1.13126526]
#  [ 1.         -0.12144651  1.12872264]]
# Measurement Matrix: [[ 1.          1.05885021 -0.08822866]
#  [ 1.         -1.14554609 -0.05466735]
#  [ 1.         -0.01611144 -1.13220849]
#  [ 1.         -0.12906937  1.12920483]]
# Measurement Matrix: [[ 1.          1.06075992 -0.0778139 ]
#  [ 1.         -1.14563591 -0.06346554]
#  [ 1.         -0.0063884  -1.13299473]
#  [ 1.         -0.13624538  1.1295592 ]]
# Measurement Matrix: [[ 1.          1.06231327 -0.06884945]
#  [ 1.         -1.14563339 -0.07111589]
#  [ 1.          0.00212936 -1.13360143]
#  [ 1.         -0.14264608  1.1297944 ]]
# Measurement Matrix: [[ 1.          1.06376593 -0.05999522]
#  [ 1.         -1.14555716 -0.07870594]
#  [ 1.          0.01025886 -1.13410932]
#  [ 1.         -0.14831794  1.1299395 ]]
# Measurement Matrix: [[ 1.          1.06496293 -0.0523001 ]
#  [ 1.         -1.1454271  -0.08549251]
#  [ 1.          0.01709751 -1.13448295]
#  [ 1.         -0.15345771  1.13001986]]
# Measurement Matrix: [[ 1.          1.06594115 -0.04570115]
#  [ 1.         -1.14523082 -0.09252768]
#  [ 1.          0.02514356 -1.13486004]
#  [ 1.         -0.15925224  1.13005245]]
# Measurement Matrix: [[ 1.          1.06698906 -0.03827409]
#  [ 1.         -1.1450852  -0.09669387]
#  [ 1.          0.0290094  -1.13501725]
#  [ 1.         -0.16246531  1.13004413]]
# Measurement Matrix: [[ 1.          1.06756059 -0.03404601]
#  [ 1.         -1.14492023 -0.10080232]
#  [ 1.          0.0339922  -1.135197  ]
#  [ 1.         -0.16575071  1.13001621]]
# Measurement Matrix: [[ 1.          1.06810871 -0.02985927]
#  [ 1.         -1.14477268 -0.1040963 ]
#  [ 1.          0.03728368 -1.13530161]
#  [ 1.         -0.16800276  1.12998577]]
# Measurement Matrix: [[ 1.          1.06846048 -0.02709827]
#  [ 1.         -1.14465798 -0.10646878]
#  [ 1.          0.03968876 -1.13537096]
#  [ 1.         -0.169576    1.12995905]]
# Measurement Matrix: [[ 1.          1.06868584 -0.02529689]
#  [ 1.         -1.14459516 -0.10771024]
#  [ 1.          0.04079991 -1.13540098]
#  [ 1.         -0.17025365  1.12994616]]
# Measurement Matrix: [[ 1.          1.06731688 -0.0358654 ]
#  [ 1.         -1.14507611 -0.09693475]
#  [ 1.          0.02727325 -1.13494857]
#  [ 1.         -0.15880946  1.13005212]]
# Measurement Matrix: [[ 1.          1.06643107 -0.04227826]
#  [ 1.         -1.14526008 -0.09160641]
#  [ 1.          0.0210704  -1.13467757]
#  [ 1.         -0.15419663  1.13002743]]
# Measurement Matrix: [[ 1.          1.06560022 -0.0480353 ]
#  [ 1.         -1.14541661 -0.08593405]
#  [ 1.          0.01456866 -1.13435048]
#  [ 1.         -0.14901549  1.12995325]]
# Measurement Matrix: [[ 1.          1.06446597 -0.0555425 ]
#  [ 1.         -1.14555334 -0.07896043]
#  [ 1.          0.00674796 -1.13389848]
#  [ 1.         -0.14276345  1.12979801]]
# Measurement Matrix: [[ 1.          1.06301148 -0.06465515]
#  [ 1.         -1.14563289 -0.07120962]
#  [ 1.         -0.00157581 -1.13334692]
#  [ 1.         -0.13648044  1.12956918]]
# Measurement Matrix: [[ 1.          1.06168359 -0.07254161]
#  [ 1.         -1.14563693 -0.0636966 ]
#  [ 1.         -0.01076087 -1.13265355]
#  [ 1.         -0.12927727  1.12921645]]
# Measurement Matrix: [[ 1.          1.05938255 -0.08538688]
#  [ 1.         -1.14550852 -0.05249199]
#  [ 1.         -0.0233976  -1.13155353]
#  [ 1.         -0.1195385   1.1285848 ]]
# Measurement Matrix: [[ 1.          1.05729672 -0.09627617]
#  [ 1.         -1.14526269 -0.04266995]
#  [ 1.         -0.03449788 -1.13044678]
#  [ 1.         -0.11112921  1.12789485]]
# Measurement Matrix: [[ 1.          1.05490921 -0.10800931]
#  [ 1.         -1.14487586 -0.03249875]
#  [ 1.         -0.04620084 -1.12913658]
#  [ 1.         -0.10206713  1.12699979]]
# Measurement Matrix: [[ 1.          1.05217225 -0.12065298]
#  [ 1.         -1.14426481 -0.02082873]
#  [ 1.         -0.05973021 -1.127437  ]
#  [ 1.         -0.09199918  1.12581881]]
# Measurement Matrix: [[ 1.          1.04907895 -0.13407289]
#  [ 1.         -1.14346166 -0.0090053 ]
#  [ 1.         -0.07203087 -1.1257181 ]
#  [ 1.         -0.08210803  1.12446476]]
# Measurement Matrix: [[ 1.          1.04582458 -0.1473536 ]
#  [ 1.         -1.14242763  0.00329085]
#  [ 1.         -0.08645403 -1.12348968]
#  [ 1.         -0.07157693  1.12280875]]
# Measurement Matrix: [[ 1.          1.04205047 -0.16184857]
#  [ 1.         -1.14114876  0.01594899]
#  [ 1.         -0.10028134 -1.12113504]
#  [ 1.         -0.06040261  1.12080576]]
# Measurement Matrix: [[ 1.          1.03784434 -0.1770336 ]
#  [ 1.         -1.13959333  0.02904619]
#  [ 1.         -0.11543249 -1.11830639]
#  [ 1.         -0.04972947  1.11865186]]
# Measurement Matrix: [[ 1.          1.03335936 -0.19227297]
#  [ 1.         -1.13774959  0.042474  ]
#  [ 1.         -0.13067609 -1.11519435]
#  [ 1.         -0.03826362  1.1160705 ]]
# Measurement Matrix: [[ 1.          1.0282924  -0.20848634]
#  [ 1.         -1.13555055  0.05649525]
#  [ 1.         -0.14682383 -1.11160181]
#  [ 1.         -0.02618629  1.11304504]]
# Measurement Matrix: [[ 1.          1.02293409 -0.22464403]
#  [ 1.         -1.1329847   0.07095134]
#  [ 1.         -0.16354391 -1.10755526]
#  [ 1.         -0.01388224  1.10963119]]
# Measurement Matrix: [[ 1.          1.01676885 -0.24216209]
#  [ 1.         -1.12982888  0.08673698]
#  [ 1.         -0.18000326 -1.10324067]
#  [ 1.         -0.00145641  1.10583428]]
# Measurement Matrix: [[ 1.          1.01031132 -0.25945489]
#  [ 1.         -1.12664415  0.10103363]
#  [ 1.         -0.19732319 -1.0983379 ]
#  [ 1.          0.01200195  1.10131338]]
# Measurement Matrix: [[ 1.          1.00343831 -0.27683831]
#  [ 1.         -1.12275572  0.11682607]
#  [ 1.         -0.21482571 -1.0929966 ]
#  [ 1.          0.02491651  1.09656192]]
# Measurement Matrix: [[ 1.          0.99585346 -0.29496305]
#  [ 1.         -1.1184125   0.13281055]
#  [ 1.         -0.23301268 -1.08702342]
#  [ 1.          0.03716566  1.09166742]]
# Measurement Matrix: [[ 1.          0.98764993 -0.31347945]
#  [ 1.         -1.11372261  0.14854916]
#  [ 1.         -0.24994154 -1.08106497]
#  [ 1.          0.05046776  1.08590744]]
# Measurement Matrix: [[ 1.          0.9791885  -0.33154541]
#  [ 1.         -1.10859815  0.16431751]
#  [ 1.         -0.26820093 -1.07419414]
#  [ 1.          0.06368681  1.0797048 ]]
# Measurement Matrix: [[ 1.          0.96981583 -0.35048449]
#  [ 1.         -1.10287583  0.18050978]
#  [ 1.         -0.28704625 -1.0666032 ]
#  [ 1.          0.07706457  1.0729186 ]]
# Measurement Matrix: [[ 1.          0.96018677 -0.36890715]
#  [ 1.         -1.09641761  0.19732955]
#  [ 1.         -0.30522798 -1.05878061]
#  [ 1.          0.09089922  1.06533353]]
# Measurement Matrix: [[ 1.          0.74304573 -0.63639972]
#  [ 1.         -0.94987462  0.41278816]
#  [ 1.         -0.545821   -0.89470385]
#  [ 1.          0.25162017  0.91605616]]
# Measurement Matrix: [[ 1.          0.76768049 -0.6151314 ]
#  [ 1.         -0.96374507  0.39956776]
#  [ 1.         -0.53035345 -0.90981184]
#  [ 1.          0.2411061   0.930982  ]]
# Measurement Matrix: [[ 1.          0.78717422 -0.59710117]
#  [ 1.         -0.98048054  0.38231178]
#  [ 1.         -0.5099263  -0.92848038]
#  [ 1.          0.22730211  0.94895778]]
# Measurement Matrix: [[ 1.          1.00751243 -0.26665277]
#  [ 1.         -1.12834805  0.09356066]
#  [ 1.         -0.18014072 -1.10320323]
#  [ 1.         -0.00735962  1.10768252]]
# Measurement Matrix: [[ 1.          1.01933491 -0.23499945]
#  [ 1.         -1.13383157  0.06636712]
#  [ 1.         -0.14964534 -1.11094244]
#  [ 1.         -0.03017005  1.11407822]]
# Measurement Matrix: [[ 1.          1.06735559 -0.03557808]
#  [ 1.         -1.14502628 -0.0982228 ]
#  [ 1.          0.02996442 -1.1350537 ]
#  [ 1.         -0.16145006  1.13004879]]
# Measurement Matrix: [[ 1.          1.06711024 -0.03738873]
#  [ 1.         -1.14511155 -0.09598394]
#  [ 1.          0.02691742 -1.13493411]
#  [ 1.         -0.15923656  1.13005245]]

# %%
print(measurement_matrix)

# %%
df = pd.load("AttributeError/home/shared/exoserver/VAMPIRES/20220127/eta_crv/rz_dpp/collapsed/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv")

plt.plot(df[double_diff_string].values != 0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the DataFrame
csv_file = "/home/shared/exoserver/VAMPIRES/20220127/eta_crv/rz_dpp/collapsed/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv"
df = pd.read_csv(csv_file)

# Specify the column name for double difference string
double_diff_string = double_diff_string  # Replace with your actual column name

# Filter the DataFrame to include only rows where the double_diff_string column is non-zero
filtered_df = df[df[double_diff_string] != 0]

# Plot every fourth value
plt.plot(filtered_df["ALTITUDE"].values[::4], filtered_df[double_diff_string].values[::4], 'o')
plt.xlabel("Altitude")
plt.ylabel(double_diff_string)
plt.title(f"{double_diff_string} vs Altitude")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the DataFrame
csv_file = "/home/shared/exoserver/VAMPIRES/20220127/eta_crv/rz_dpp/collapsed/20240111_Eta_Crv_675_nm_Header_Parameters_R_15_Aperture_with_errors.csv"
df = pd.read_csv(csv_file)

# Specify the column name for double difference string
double_diff_string = "UNNORMALIZED_DOUBLE_DIFFERENCE"  # Replace with your actual column name

# Filter the DataFrame to include only rows where the double_diff_string column is non-zero
filtered_df = df[df[double_diff_string] != 0]

# Plot every fourth value
plt.plot(filtered_df["ALTITUDE"].values[::4], filtered_df[double_diff_string].values[::4], 'o')
plt.xlabel("Altitude")
plt.ylabel(double_diff_string)
plt.title(f"{double_diff_string} vs Altitude")
plt.grid(True)
plt.show()

# %% [markdown]
# # Plotting in the On-Sky Frame

# %%
# Extract unique objects and generate colors
unique_objects = all_data['OBJECT'].unique()
colors = itertools.cycle(plt.cm.tab10.colors)  # Use a colormap with a cycle of 10 colors

# Initialize lists for storing the results
wavelength = 675
Q_list = []
U_list = []
Q_err_list = []
U_err_list = []
final_altitudes = []

model = matrices.full_system_mueller_matrix

# Loop through each unique object
for obj in unique_objects:
    object_data = all_data[all_data['OBJECT'] == obj]
    color = next(colors)

    # Initialize lists for this object
    first_rows = []
    inst_matrices_at_HWP = []
    this_cycle_intensities = []
    this_cycle_altitudes = []
    this_cycle_errors = []

    for i, row in object_data.iterrows():
        HWP_ang = row["U_HWPANG"]
        IMR_ang = row["D_IMRANG"]
        cam_num = row["U_CAMERA"]
        FLC_state = row["U_FLCSTT"]
        altitude = row["ALTITUDE"]
        parang = row["PA"]
        data_Q = row["Q"]

        # NOTE: This is for normalized differences
        double_difference = row[double_diff_string]
        # double_sum = row["DOUBLE_SUM"]
        double_difference_err = row["DOUBLE_DIFFERENCE_ERRS"]

        if double_difference != 0:
            # Append intensities and altitudes for this cycle
            this_cycle_intensities.append(double_difference)
            this_cycle_altitudes.append(altitude)
            this_cycle_errors.append(double_difference_err)

            print("Parallactic Angle: " + str(parang) + " Altitude: " + str(altitude) + " HWP Angle: " + str(HWP_ang) + " IMR Angle: " + str(IMR_ang))

            # Calculate instrument matrix for equatorial reference frame
            # these_inst_matrices_at_HWP = matrices.full_system_mueller_matrix_normalized_double_diff_and_sum(
            #     model, fixed_params, parang, altitude, HWP_ang, IMR_ang, factor = double_diff_factor)
            # Calculate instrument matrix at HWP
            these_inst_matrices_at_HWP = matrices.full_system_mueller_matrix_normalized_double_diff_and_sum(
                model, fixed_params, 0, 0, HWP_ang, IMR_ang, factor = double_diff_factor)
            double_diff_matrix_at_HWP = these_inst_matrices_at_HWP[0]
            double_sum_matrix_at_HWP = these_inst_matrices_at_HWP[1]

            # Setting the I component to be 1
            double_diff_matrix_at_HWP[0, 0] = 1

            # Saving instrument matrices
            inst_matrices_at_HWP.append(double_diff_matrix_at_HWP)
            inst_matrices_at_HWP.append(double_sum_matrix_at_HWP)

            # Take only the first row and I, Q, U, components (no V)
            first_rows.append(double_diff_matrix_at_HWP[0, : 3])  

        # Do one inversion for one HWP cycle
        if data_Q != 0:
            # Constructing measurement matrix to reconstruct Stokes vector at HWP
            measurement_matrix = np.vstack(first_rows)
            measurements = np.array(this_cycle_intensities).reshape(-1, 1)  # Reshape total counts to a column vector
            errors = np.array(this_cycle_errors).reshape(-1, 1)  # Reshape errors to a column vector

            # Compute the pseudo-inverse of the measurement matrix and multiply it by the measurements vector
            s_HWP = np.linalg.pinv(measurement_matrix) @ measurements

            # Compute the errors for the Stokes parameters
            s_HWP_err = np.linalg.pinv(measurement_matrix) @ errors

            # Extract Q and U from s_HWP and their errors
            Q = s_HWP[1]
            U = s_HWP[2]
            Q_err = s_HWP_err[1]
            U_err = s_HWP_err[2]

            # Append Q, U, altitude, and errors to the lists
            Q_list.append((altitude, Q, color, obj))
            U_list.append((altitude, U, color, obj))
            Q_err_list.append(Q_err)
            U_err_list.append(U_err)

            # Saving the mean of the altitudes
            mean_altitude = np.mean(this_cycle_altitudes)

            # Reset measurement matrix rows and double diff and sum measurements
            first_rows = []  
            this_cycle_intensities = []
            this_cycle_altitudes = []
            this_cycle_errors = []

            final_altitudes.append(mean_altitude)

# TODO: See if it's ok to just take the absolute uncertainties
Q_err_list = np.abs(Q_err_list)
U_err_list = np.abs(U_err_list)

# Plotting
plt.figure(figsize=(12, 8))
plotted_labels = set()
for (altitude, Q, color, obj), Q_err in zip(Q_list, Q_err_list):
    label = f'Q - {obj}' if f'Q - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, Q, yerr=Q_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor=color)
    plotted_labels.add(f'Q - {obj}')

for (altitude, U, color, obj), U_err in zip(U_list, U_err_list):
    label = f'U - {obj}' if f'U - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, U, yerr=U_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor='none', markeredgecolor=color)
    plotted_labels.add(f'U - {obj}')

plt.title(f"Stokes Q and U of {wavelength}nm Eta Crv Data @ HWP - EM Gain Ratio = " + str(em_gain))
plt.xlabel("Altitude (Degrees)")
plt.ylabel("Stokes (Q/U)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Parallactic Angle: -84.9084509958819 Altitude: 56.56625 HWP Angle: 0.0 IMR Angle: 92.72502
# Parallactic Angle: -84.92782440447132 Altitude: 56.6469 HWP Angle: 45.0 IMR Angle: 92.75622
# Parallactic Angle: -84.94601513329397 Altitude: 56.72251 HWP Angle: 22.5 IMR Angle: 92.774
# Parallactic Angle: -84.96558157041534 Altitude: 56.80395 HWP Angle: 67.5 IMR Angle: 92.83803
# Parallactic Angle: -84.98557673519853 Altitude: 56.88694 HWP Angle: 0.0 IMR Angle: 92.88425
# Parallactic Angle: -85.00475344133699 Altitude: 56.96644 HWP Angle: 45.0 IMR Angle: 92.9218
# Parallactic Angle: -85.02352809078987 Altitude: 57.04475 HWP Angle: 22.5 IMR Angle: 92.96298
# Parallactic Angle: -85.04303906901262 Altitude: 57.1258 HWP Angle: 67.5 IMR Angle: 93.00444
# Parallactic Angle: -85.06352335313669 Altitude: 57.21077 HWP Angle: 0.0 IMR Angle: 93.04548
# Parallactic Angle: -85.08298858276943 Altitude: 57.29144 HWP Angle: 45.0 IMR Angle: 93.07996
# Parallactic Angle: -85.1012730269808 Altitude: 57.36742 HWP Angle: 22.5 IMR Angle: 93.12207
# Parallactic Angle: -85.12038116090851 Altitude: 57.44655 HWP Angle: 67.5 IMR Angle: 93.16294
# Parallactic Angle: -85.14069170644963 Altitude: 57.53035 HWP Angle: 0.0 IMR Angle: 93.20705
# Parallactic Angle: -85.15983230956532 Altitude: 57.60984 HWP Angle: 45.0 IMR Angle: 93.24827
# Parallactic Angle: -85.17829932387816 Altitude: 57.68626 HWP Angle: 22.5 IMR Angle: 93.27139
# Parallactic Angle: -85.19749886580391 Altitude: 57.76577 HWP Angle: 67.5 IMR Angle: 93.33156
# Parallactic Angle: -85.21802572339895 Altitude: 57.85073 HWP Angle: 0.0 IMR Angle: 93.36338
# Parallactic Angle: -85.23781605200702 Altitude: 57.93258 HWP Angle: 45.0 IMR Angle: 93.40598
# Parallactic Angle: -85.25672609224777 Altitude: 58.01057 HWP Angle: 22.5 IMR Angle: 93.44571
# Parallactic Angle: -85.2763716447274 Altitude: 58.09165 HWP Angle: 67.5 IMR Angle: 93.48595
# Parallactic Angle: -86.2976600230996 Altitude: 62.23723 HWP Angle: 0.0 IMR Angle: 95.5587
# Parallactic Angle: -86.3182380753786 Altitude: 62.31879 HWP Angle: 45.0 IMR Angle: 95.59656
# Parallactic Angle: -86.33728924278304 Altitude: 62.39453 HWP Angle: 22.5 IMR Angle: 95.63591
# Parallactic Angle: -86.3582803798566 Altitude: 62.47729 HWP Angle: 67.5 IMR Angle: 95.68089
# Parallactic Angle: -86.38006084821279 Altitude: 62.56396 HWP Angle: 0.0 IMR Angle: 95.72379
# Parallactic Angle: -86.40062652585912 Altitude: 62.64517 HWP Angle: 45.0 IMR Angle: 95.75931
# Parallactic Angle: -86.42039345847705 Altitude: 62.72361 HWP Angle: 22.5 IMR Angle: 95.80091
# Parallactic Angle: -86.4405594583239 Altitude: 62.80327 HWP Angle: 67.5 IMR Angle: 95.84202
# Parallactic Angle: -86.46226832423984 Altitude: 62.88878 HWP Angle: 0.0 IMR Angle: 95.8842
# Parallactic Angle: -86.48226253942522 Altitude: 62.96763 HWP Angle: 45.0 IMR Angle: 95.92317
# Parallactic Angle: -86.50193135149051 Altitude: 63.04456 HWP Angle: 22.5 IMR Angle: 95.96293
# Parallactic Angle: -86.52250006980299 Altitude: 63.12577 HWP Angle: 67.5 IMR Angle: 96.00694
# Parallactic Angle: -86.54408760837619 Altitude: 63.21049 HWP Angle: 0.0 IMR Angle: 96.04598
# Parallactic Angle: -86.56447180363052 Altitude: 63.29052 HWP Angle: 45.0 IMR Angle: 96.08623
# Parallactic Angle: -86.5840621383825 Altitude: 63.36746 HWP Angle: 22.5 IMR Angle: 96.1233
# Parallactic Angle: -86.60436621309077 Altitude: 63.44712 HWP Angle: 67.5 IMR Angle: 96.16213
# Parallactic Angle: -86.62583093353548 Altitude: 63.53106 HWP Angle: 0.0 IMR Angle: 96.20659
# Parallactic Angle: -86.64662980050177 Altitude: 63.61228 HWP Angle: 45.0 IMR Angle: 96.24635
# Parallactic Angle: -86.66621762439505 Altitude: 63.68843 HWP Angle: 22.5 IMR Angle: 96.28947
# Parallactic Angle: -86.68704348999401 Altitude: 63.76966 HWP Angle: 67.5 IMR Angle: 96.32799
# Parallactic Angle: -87.80283907532478 Altitude: 67.95023 HWP Angle: 0.0 IMR Angle: 98.41813
# Parallactic Angle: -87.82530836925432 Altitude: 68.03036 HWP Angle: 45.0 IMR Angle: 98.45882
# Parallactic Angle: -87.84673728051044 Altitude: 68.10736 HWP Angle: 22.5 IMR Angle: 98.49541
# Parallactic Angle: -87.86950315688372 Altitude: 68.18827 HWP Angle: 67.5 IMR Angle: 98.53476
# Parallactic Angle: -87.89366602591267 Altitude: 68.27429 HWP Angle: 0.0 IMR Angle: 98.58074
# Parallactic Angle: -87.91650731369751 Altitude: 68.3548 HWP Angle: 45.0 IMR Angle: 98.61736
# Parallactic Angle: -87.93807142550429 Altitude: 68.43142 HWP Angle: 22.5 IMR Angle: 98.65592
# Parallactic Angle: -87.96085539656404 Altitude: 68.51156 HWP Angle: 67.5 IMR Angle: 98.69668
# Parallactic Angle: -87.98539349313393 Altitude: 68.59756 HWP Angle: 0.0 IMR Angle: 98.73993
# Parallactic Angle: -88.00817934881559 Altitude: 68.6785 HWP Angle: 45.0 IMR Angle: 98.77631
# Parallactic Angle: -88.0306948813047 Altitude: 68.75706 HWP Angle: 22.5 IMR Angle: 98.81884
# Parallactic Angle: -88.05337550886142 Altitude: 68.83681 HWP Angle: 67.5 IMR Angle: 98.85529
# Parallactic Angle: -88.07745986487642 Altitude: 68.92088 HWP Angle: 0.0 IMR Angle: 98.90358
# Parallactic Angle: -88.10086138952451 Altitude: 69.0018 HWP Angle: 45.0 IMR Angle: 98.94145
# Parallactic Angle: -88.12341489860239 Altitude: 69.08038 HWP Angle: 22.5 IMR Angle: 98.97979
# Parallactic Angle: -88.14603771233692 Altitude: 69.15897 HWP Angle: 67.5 IMR Angle: 99.01966
# Parallactic Angle: -88.17068085111593 Altitude: 69.24381 HWP Angle: 0.0 IMR Angle: 99.06315
# Parallactic Angle: -88.19407725515669 Altitude: 69.32435 HWP Angle: 45.0 IMR Angle: 99.0967
# Parallactic Angle: -88.21590288777064 Altitude: 69.39981 HWP Angle: 22.5 IMR Angle: 99.13871
# Parallactic Angle: -88.23936775628246 Altitude: 69.48036 HWP Angle: 67.5 IMR Angle: 99.17589
# Parallactic Angle: 170.1471114528957 Altitude: 85.75207 HWP Angle: 0.0 IMR Angle: 107.36972
# Parallactic Angle: 167.6205632422972 Altitude: 85.72787 HWP Angle: 45.0 IMR Angle: 107.36969
# Parallactic Angle: 166.0440630229906 Altitude: 85.70915 HWP Angle: 22.5 IMR Angle: 107.3604
# Parallactic Angle: 164.4404652272129 Altitude: 85.68556 HWP Angle: 67.5 IMR Angle: 107.35025
# Parallactic Angle: 162.8602984217002 Altitude: 85.65928 HWP Angle: 0.0 IMR Angle: 107.32678
# Parallactic Angle: 161.3511163687652 Altitude: 85.62945 HWP Angle: 45.0 IMR Angle: 107.29972
# Parallactic Angle: 159.9613111783035 Altitude: 85.59906 HWP Angle: 22.5 IMR Angle: 107.29972
# Parallactic Angle: 158.4575288535741 Altitude: 85.56379 HWP Angle: 67.5 IMR Angle: 107.28274
# Parallactic Angle: 105.2299474619039 Altitude: 76.59692 HWP Angle: 0.0 IMR Angle: 102.80188
# Parallactic Angle: 104.9478705038061 Altitude: 76.41757 HWP Angle: 45.0 IMR Angle: 102.72373
# Parallactic Angle: 104.7780572987302 Altitude: 76.3035 HWP Angle: 22.5 IMR Angle: 102.66471
# Parallactic Angle: 104.5942948675035 Altitude: 76.18603 HWP Angle: 67.5 IMR Angle: 102.60358
# Parallactic Angle: 104.4237895067571 Altitude: 76.06991 HWP Angle: 0.0 IMR Angle: 102.54007
# Parallactic Angle: 104.2611998087403 Altitude: 75.95851 HWP Angle: 45.0 IMR Angle: 102.48594
# Parallactic Angle: 104.0977002962421 Altitude: 75.84738 HWP Angle: 22.5 IMR Angle: 102.42896
# Parallactic Angle: 103.9313699916159 Altitude: 75.7299 HWP Angle: 67.5 IMR Angle: 102.37521
# Parallactic Angle: 90.50439505424674 Altitude: 57.74918 HWP Angle: 0.0 IMR Angle: 93.3861
# Parallactic Angle: 90.42914210082157 Altitude: 57.58897 HWP Angle: 45.0 IMR Angle: 93.29172
# Parallactic Angle: 90.37845113139868 Altitude: 57.47604 HWP Angle: 22.5 IMR Angle: 93.24112
# Parallactic Angle: 90.3210419338484 Altitude: 57.35279 HWP Angle: 67.5 IMR Angle: 93.18917
# Parallactic Angle: 90.26575902636787 Altitude: 57.23036 HWP Angle: 0.0 IMR Angle: 93.12922
# Parallactic Angle: 90.21221473285206 Altitude: 57.10977 HWP Angle: 45.0 IMR Angle: 93.06736
# Parallactic Angle: 90.11071768588974 Altitude: 56.88509 HWP Angle: 22.5 IMR Angle: 92.9539
# Parallactic Angle: 90.05614074535112 Altitude: 56.76072 HWP Angle: 67.5 IMR Angle: 92.89674
# Parallactic Angle: 80.5354437156401 Altitude: 78.46411 HWP Angle: 0.0 IMR Angle: 103.78977
# Parallactic Angle: 80.57337439874374 Altitude: 78.38437 HWP Angle: 45.0 IMR Angle: 103.74438
# Parallactic Angle: 80.60711977183695 Altitude: 78.30814 HWP Angle: 22.5 IMR Angle: 103.70569
# Parallactic Angle: 80.64379922671391 Altitude: 78.22761 HWP Angle: 67.5 IMR Angle: 103.67787
# Parallactic Angle: 80.68159303839636 Altitude: 78.14237 HWP Angle: 0.0 IMR Angle: 103.6313
# Parallactic Angle: 80.71509496781177 Altitude: 78.06221 HWP Angle: 45.0 IMR Angle: 103.59295
# Parallactic Angle: 80.74825249291936 Altitude: 77.98242 HWP Angle: 22.5 IMR Angle: 103.54025
# Parallactic Angle: 80.78224516367858 Altitude: 77.90223 HWP Angle: 67.5 IMR Angle: 103.51588
# Parallactic Angle: 80.8155050156637 Altitude: 77.81812 HWP Angle: 0.0 IMR Angle: 103.47062
# Parallactic Angle: 80.8481954569473 Altitude: 77.73792 HWP Angle: 45.0 IMR Angle: 103.41781
# Parallactic Angle: 80.87891470549677 Altitude: 77.66161 HWP Angle: 22.5 IMR Angle: 103.39275
# Parallactic Angle: 80.90894622511294 Altitude: 77.57904 HWP Angle: 67.5 IMR Angle: 103.35396
# Parallactic Angle: 82.01252298075299 Altitude: 72.6184 HWP Angle: 0.0 IMR Angle: 100.86804
# Parallactic Angle: 82.02097090954936 Altitude: 72.53672 HWP Angle: 45.0 IMR Angle: 100.81233
# Parallactic Angle: 82.02922976537789 Altitude: 72.45974 HWP Angle: 22.5 IMR Angle: 100.78316
# Parallactic Angle: 82.0377031131982 Altitude: 72.37764 HWP Angle: 67.5 IMR Angle: 100.74909
# Parallactic Angle: 82.04592557568114 Altitude: 72.29281 HWP Angle: 0.0 IMR Angle: 100.70643
# Parallactic Angle: 82.05394455801724 Altitude: 72.21349 HWP Angle: 45.0 IMR Angle: 100.6589
# Parallactic Angle: 82.0612273452696 Altitude: 72.13491 HWP Angle: 22.5 IMR Angle: 100.63515
# Parallactic Angle: 82.06880442725544 Altitude: 72.05283 HWP Angle: 67.5 IMR Angle: 100.59014
# Parallactic Angle: 82.07643484034406 Altitude: 71.96877 HWP Angle: 0.0 IMR Angle: 100.54292
# Parallactic Angle: 82.08325869206472 Altitude: 71.88706 HWP Angle: 45.0 IMR Angle: 100.50685
# Parallactic Angle: 82.0901304409991 Altitude: 71.80852 HWP Angle: 22.5 IMR Angle: 100.46408
# Parallactic Angle: 82.09718085598989 Altitude: 71.72522 HWP Angle: 67.5 IMR Angle: 100.41365
# Parallactic Angle: -50.93950816162588 Altitude: 34.43197 HWP Angle: 0.0 IMR Angle: 81.71725
# Parallactic Angle: -50.39210056664232 Altitude: 35.00908 HWP Angle: 45.0 IMR Angle: 82.00788
# Parallactic Angle: -50.20120626758227 Altitude: 35.20673 HWP Angle: 22.5 IMR Angle: 82.10674
# Parallactic Angle: -50.00292853394922 Altitude: 35.41028 HWP Angle: 67.5 IMR Angle: 82.20664
# Parallactic Angle: -49.8032586580409 Altitude: 35.61293 HWP Angle: 0.0 IMR Angle: 82.30898
# Parallactic Angle: -49.60837711547795 Altitude: 35.80827 HWP Angle: 45.0 IMR Angle: 82.40863
# Parallactic Angle: -49.41214379093759 Altitude: 36.00364 HWP Angle: 22.5 IMR Angle: 82.50501
# Parallactic Angle: -49.20969675514404 Altitude: 36.20362 HWP Angle: 67.5 IMR Angle: 82.60593
# Parallactic Angle: -49.00455147325459 Altitude: 36.4039 HWP Angle: 0.0 IMR Angle: 82.70093
# Parallactic Angle: -48.80232800017597 Altitude: 36.60053 HWP Angle: 45.0 IMR Angle: 82.80303
# Parallactic Angle: -48.6020891277835 Altitude: 36.79084 HWP Angle: 22.5 IMR Angle: 82.89519
# Parallactic Angle: -48.39086175613556 Altitude: 36.99108 HWP Angle: 67.5 IMR Angle: 82.99557
# Parallactic Angle: -48.18119731053719 Altitude: 37.18676 HWP Angle: 0.0 IMR Angle: 83.09032
# Parallactic Angle: -47.97493576902931 Altitude: 37.37764 HWP Angle: 45.0 IMR Angle: 83.18894
# Parallactic Angle: -47.76720247933783 Altitude: 37.5682 HWP Angle: 22.5 IMR Angle: 83.27968
# Parallactic Angle: -47.54168653109342 Altitude: 37.78213 HWP Angle: 67.5 IMR Angle: 83.38831
# Parallactic Angle: -47.28634650345644 Altitude: 38.00322 HWP Angle: 0.0 IMR Angle: 83.49773
# Parallactic Angle: -46.90517336264107 Altitude: 38.34202 HWP Angle: 45.0 IMR Angle: 83.67273
# Parallactic Angle: -46.68992287236752 Altitude: 38.5264 HWP Angle: 22.5 IMR Angle: 83.7603
# Parallactic Angle: -46.46632570698368 Altitude: 38.7189 HWP Angle: 67.5 IMR Angle: 83.85692
# Parallactic Angle: -46.24295835369615 Altitude: 38.9098 HWP Angle: 0.0 IMR Angle: 83.95443
# Parallactic Angle: -46.02315343223477 Altitude: 39.0942 HWP Angle: 45.0 IMR Angle: 84.04607
# Parallactic Angle: -45.80357005950703 Altitude: 39.27794 HWP Angle: 22.5 IMR Angle: 84.13855
# Parallactic Angle: -45.57175507610602 Altitude: 39.46902 HWP Angle: 67.5 IMR Angle: 84.23264
# Parallactic Angle: -45.19378393853974 Altitude: 39.7766 HWP Angle: 0.0 IMR Angle: 84.38714
# Parallactic Angle: -44.88451813570504 Altitude: 40.02327 HWP Angle: 45.0 IMR Angle: 84.51147
# Parallactic Angle: -44.65524412604083 Altitude: 40.20428 HWP Angle: 22.5 IMR Angle: 84.60319
# Parallactic Angle: -44.41701723420942 Altitude: 40.39188 HWP Angle: 67.5 IMR Angle: 84.69583
# Parallactic Angle: -44.17705609579158 Altitude: 40.57505 HWP Angle: 0.0 IMR Angle: 84.78254
# Parallactic Angle: -43.94258814528796 Altitude: 40.7541 HWP Angle: 45.0 IMR Angle: 84.87505
# Parallactic Angle: -43.69568756707937 Altitude: 40.94126 HWP Angle: 22.5 IMR Angle: 84.96949
# Parallactic Angle: -43.46170319097174 Altitude: 41.11488 HWP Angle: 67.5 IMR Angle: 85.05592
# Parallactic Angle: -43.21661423135483 Altitude: 41.29601 HWP Angle: 0.0 IMR Angle: 85.15198
# Parallactic Angle: -42.97367795326409 Altitude: 41.47249 HWP Angle: 45.0 IMR Angle: 85.23679
# Parallactic Angle: -42.73279199285076 Altitude: 41.64625 HWP Angle: 22.5 IMR Angle: 85.32477
# Parallactic Angle: -42.48073488186673 Altitude: 41.82684 HWP Angle: 67.5 IMR Angle: 85.41266
# Parallactic Angle: -42.22678594395328 Altitude: 42.00386 HWP Angle: 0.0 IMR Angle: 85.50257
# Parallactic Angle: -41.97682969105045 Altitude: 42.17786 HWP Angle: 45.0 IMR Angle: 85.5887
# Parallactic Angle: -41.73095075769027 Altitude: 42.34783 HWP Angle: 22.5 IMR Angle: 85.67451
# Parallactic Angle: -41.47166145147494 Altitude: 42.52523 HWP Angle: 67.5 IMR Angle: 85.76249
# Parallactic Angle: -41.20837635912514 Altitude: 42.69934 HWP Angle: 0.0 IMR Angle: 85.8513
# Parallactic Angle: -40.95345524245472 Altitude: 42.86834 HWP Angle: 45.0 IMR Angle: 85.93553
# Parallactic Angle: -40.69863165946601 Altitude: 43.03596 HWP Angle: 22.5 IMR Angle: 86.01799
# Parallactic Angle: -40.43173200839238 Altitude: 43.20766 HWP Angle: 67.5 IMR Angle: 86.10525
# Parallactic Angle: -40.16311934781685 Altitude: 43.37896 HWP Angle: 0.0 IMR Angle: 86.18771
# Parallactic Angle: -39.9009209392693 Altitude: 43.54595 HWP Angle: 45.0 IMR Angle: 86.27338
# Parallactic Angle: -39.63661268220802 Altitude: 43.70949 HWP Angle: 22.5 IMR Angle: 86.35378
# Parallactic Angle: -39.36224637667422 Altitude: 43.87797 HWP Angle: 67.5 IMR Angle: 86.437
# Parallactic Angle: -39.08824313273934 Altitude: 44.04397 HWP Angle: 0.0 IMR Angle: 86.51863
# Parallactic Angle: -38.81640811211871 Altitude: 44.20698 HWP Angle: 45.0 IMR Angle: 86.60203
# Parallactic Angle: -38.26710357745998 Altitude: 44.53064 HWP Angle: 22.5 IMR Angle: 86.75794
# Parallactic Angle: -37.98538292249033 Altitude: 44.69298 HWP Angle: 67.5 IMR Angle: 86.84389
# Parallactic Angle: -30.87997358959448 Altitude: 48.15789 HWP Angle: 0.0 IMR Angle: 88.57591
# Parallactic Angle: -29.9934665667947 Altitude: 48.51489 HWP Angle: 45.0 IMR Angle: 88.75036
# Parallactic Angle: -29.67221856649607 Altitude: 48.63661 HWP Angle: 22.5 IMR Angle: 88.81567
# Parallactic Angle: -23.90200564020192 Altitude: 50.58191 HWP Angle: 0.0 IMR Angle: 89.78796
# Parallactic Angle: -23.30525053122422 Altitude: 50.75346 HWP Angle: 45.0 IMR Angle: 89.87335
# Parallactic Angle: -22.93927200574094 Altitude: 50.85381 HWP Angle: 22.5 IMR Angle: 89.92468
# Parallactic Angle: -22.56246207324125 Altitude: 50.9564 HWP Angle: 67.5 IMR Angle: 89.9747
# Parallactic Angle: -22.18102327312891 Altitude: 51.05786 HWP Angle: 0.0 IMR Angle: 90.02354
# Parallactic Angle: -21.80947923134745 Altitude: 51.15486 HWP Angle: 45.0 IMR Angle: 90.07193
# Parallactic Angle: -21.43612059067155 Altitude: 51.25017 HWP Angle: 22.5 IMR Angle: 90.11881
# Parallactic Angle: -21.05181720121384 Altitude: 51.34639 HWP Angle: 67.5 IMR Angle: 90.16761
# Parallactic Angle: -20.66288944476832 Altitude: 51.44183 HWP Angle: 0.0 IMR Angle: 90.2139
# Parallactic Angle: -20.28414892885462 Altitude: 51.53251 HWP Angle: 45.0 IMR Angle: 90.25964
# Parallactic Angle: -19.90370529310945 Altitude: 51.62119 HWP Angle: 22.5 IMR Angle: 90.30534
# Parallactic Angle: -19.51229730010573 Altitude: 51.71168 HWP Angle: 67.5 IMR Angle: 90.35142
# Parallactic Angle: -19.11331917869987 Altitude: 51.79991 HWP Angle: 0.0 IMR Angle: 90.3935
# Parallactic Angle: -18.7274629256186 Altitude: 51.88422 HWP Angle: 45.0 IMR Angle: 90.43723
# Parallactic Angle: -18.34022606228919 Altitude: 51.96664 HWP Angle: 22.5 IMR Angle: 90.47613
# Parallactic Angle: -17.94214623990482 Altitude: 52.04943 HWP Angle: 67.5 IMR Angle: 90.5189
# Parallactic Angle: -17.53926713342963 Altitude: 52.13171 HWP Angle: 0.0 IMR Angle: 90.5618
# Parallactic Angle: -17.14395876642385 Altitude: 52.20909 HWP Angle: 45.0 IMR Angle: 90.59929
# Parallactic Angle: -16.753303037517 Altitude: 52.28456 HWP Angle: 22.5 IMR Angle: 90.63681
# Parallactic Angle: -16.34552250427372 Altitude: 52.361 HWP Angle: 67.5 IMR Angle: 90.67606
# Parallactic Angle: -15.93652313288444 Altitude: 52.43577 HWP Angle: 0.0 IMR Angle: 90.70629
# Parallactic Angle: -15.53802915326148 Altitude: 52.50664 HWP Angle: 45.0 IMR Angle: 90.73985
# Parallactic Angle: -15.13809033588204 Altitude: 52.57537 HWP Angle: 22.5 IMR Angle: 90.77726
# Parallactic Angle: -14.72782606652077 Altitude: 52.64404 HWP Angle: 67.5 IMR Angle: 90.81585
# Parallactic Angle: -14.30925842817447 Altitude: 52.71171 HWP Angle: 0.0 IMR Angle: 90.84868
# Parallactic Angle: -13.90844619448106 Altitude: 52.77517 HWP Angle: 45.0 IMR Angle: 90.87899
# Parallactic Angle: -13.50298576043999 Altitude: 52.83708 HWP Angle: 22.5 IMR Angle: 90.91105
# Parallactic Angle: -13.08387783627908 Altitude: 52.89926 HWP Angle: 67.5 IMR Angle: 90.93943
# Parallactic Angle: -12.6599435125655 Altitude: 52.95948 HWP Angle: 0.0 IMR Angle: 90.97218
# Parallactic Angle: -12.2541560097453 Altitude: 53.01562 HWP Angle: 45.0 IMR Angle: 91.00315
# Parallactic Angle: -11.84675383723629 Altitude: 53.07052 HWP Angle: 22.5 IMR Angle: 91.02341
# Parallactic Angle: -11.41930736230171 Altitude: 53.12498 HWP Angle: 67.5 IMR Angle: 91.05119
# Parallactic Angle: -10.99369999139245 Altitude: 53.17762 HWP Angle: 0.0 IMR Angle: 91.07791
# Parallactic Angle: -10.16213808653316 Altitude: 53.27459 HWP Angle: 45.0 IMR Angle: 91.13162
# Parallactic Angle: -9.74647964132967 Altitude: 53.32036 HWP Angle: 22.5 IMR Angle: 91.1554
# Parallactic Angle: -9.31663577501797 Altitude: 53.36523 HWP Angle: 67.5 IMR Angle: 91.17694
# Parallactic Angle: -8.885760572689883 Altitude: 53.40834 HWP Angle: 0.0 IMR Angle: 91.19672
# Parallactic Angle: -8.466953525194379 Altitude: 53.44835 HWP Angle: 45.0 IMR Angle: 91.20759
# Parallactic Angle: -8.04767093705099 Altitude: 53.48656 HWP Angle: 22.5 IMR Angle: 91.21874
# Parallactic Angle: -7.610743270734456 Altitude: 53.524 HWP Angle: 67.5 IMR Angle: 91.24656
# Parallactic Angle: -7.183217685946365 Altitude: 53.55883 HWP Angle: 0.0 IMR Angle: 91.26427
# Parallactic Angle: -6.758164286484777 Altitude: 53.59145 HWP Angle: 45.0 IMR Angle: 91.28243
# Parallactic Angle: -6.338870080786813 Altitude: 53.62181 HWP Angle: 22.5 IMR Angle: 91.30031
# Parallactic Angle: -5.902711009746832 Altitude: 53.65135 HWP Angle: 67.5 IMR Angle: 91.31767
# Parallactic Angle: -5.460952881059946 Altitude: 53.6785 HWP Angle: 0.0 IMR Angle: 91.3311
# Parallactic Angle: -5.036628904755141 Altitude: 53.70313 HWP Angle: 45.0 IMR Angle: 91.34238
# Parallactic Angle: -4.611601408022217 Altitude: 53.72614 HWP Angle: 22.5 IMR Angle: 91.35415
# Parallactic Angle: -4.179496377087749 Altitude: 53.74754 HWP Angle: 67.5 IMR Angle: 91.36637
# Parallactic Angle: -3.740609081071063 Altitude: 53.76728 HWP Angle: 0.0 IMR Angle: 91.37514
# Parallactic Angle: -3.311048956781393 Altitude: 53.78449 HWP Angle: 45.0 IMR Angle: 91.38553
# Parallactic Angle: -2.887555408468341 Altitude: 53.79958 HWP Angle: 22.5 IMR Angle: 91.39347
# Parallactic Angle: -2.444049022639637 Altitude: 53.81325 HWP Angle: 67.5 IMR Angle: 91.40037
# Parallactic Angle: -2.007010228950239 Altitude: 53.82494 HWP Angle: 0.0 IMR Angle: 91.40386
# Parallactic Angle: -1.579888079802597 Altitude: 53.83424 HWP Angle: 45.0 IMR Angle: 91.4081
# Parallactic Angle: -1.149047688316258 Altitude: 53.84181 HWP Angle: 22.5 IMR Angle: 91.41163
# Parallactic Angle: -0.7111360879199538 Altitude: 53.84745 HWP Angle: 67.5 IMR Angle: 91.41501
# Parallactic Angle: 8.879276495211341 Altitude: 53.46532 HWP Angle: 0.0 IMR Angle: 91.23521
# Parallactic Angle: 9.678180843974353 Altitude: 53.38891 HWP Angle: 45.0 IMR Angle: 91.21198
# Parallactic Angle: 10.09063155600811 Altitude: 53.34637 HWP Angle: 22.5 IMR Angle: 91.1903
# Parallactic Angle: 10.5216708948127 Altitude: 53.30017 HWP Angle: 67.5 IMR Angle: 91.16734
# Parallactic Angle: 10.94850783305982 Altitude: 53.25259 HWP Angle: 0.0 IMR Angle: 91.13269
# Parallactic Angle: 11.36140872338184 Altitude: 53.20447 HWP Angle: 45.0 IMR Angle: 91.11481
# Parallactic Angle: 11.76990249842918 Altitude: 53.15487 HWP Angle: 22.5 IMR Angle: 91.08861
# Parallactic Angle: 12.19304573426585 Altitude: 53.10094 HWP Angle: 67.5 IMR Angle: 91.06724
# Parallactic Angle: 12.61514186931058 Altitude: 53.04566 HWP Angle: 0.0 IMR Angle: 91.04053
# Parallactic Angle: 13.02631887395794 Altitude: 52.99016 HWP Angle: 45.0 IMR Angle: 91.01122
# Parallactic Angle: 13.43023638380838 Altitude: 52.93333 HWP Angle: 22.5 IMR Angle: 90.98188
# Parallactic Angle: 13.84819498652496 Altitude: 52.87234 HWP Angle: 67.5 IMR Angle: 90.95461
# Parallactic Angle: 14.26504684166674 Altitude: 52.80964 HWP Angle: 0.0 IMR Angle: 90.92017
# Parallactic Angle: 14.66771076757157 Altitude: 52.74689 HWP Angle: 45.0 IMR Angle: 90.88365
# Parallactic Angle: 15.06924012106137 Altitude: 52.68237 HWP Angle: 22.5 IMR Angle: 90.8533
# Parallactic Angle: 15.47864233930761 Altitude: 52.61487 HWP Angle: 67.5 IMR Angle: 90.81841
# Parallactic Angle: 15.89286434516817 Altitude: 52.54437 HWP Angle: 0.0 IMR Angle: 90.77378
# Parallactic Angle: 16.28976605341771 Altitude: 52.47457 HWP Angle: 45.0 IMR Angle: 90.74157
# Parallactic Angle: 16.68518183697707 Altitude: 52.40328 HWP Angle: 22.5 IMR Angle: 90.7162
# Parallactic Angle: 17.08862502588555 Altitude: 52.32822 HWP Angle: 67.5 IMR Angle: 90.6812
# Parallactic Angle: 17.49018590014062 Altitude: 52.25127 HWP Angle: 0.0 IMR Angle: 90.64682
# Parallactic Angle: 17.88721271755576 Altitude: 52.174 HWP Angle: 45.0 IMR Angle: 90.60354
# Parallactic Angle: 18.27634400875429 Altitude: 52.09527 HWP Angle: 22.5 IMR Angle: 90.5646
# Parallactic Angle: 18.6700824550487 Altitude: 52.01398 HWP Angle: 67.5 IMR Angle: 90.52346
# Parallactic Angle: 19.46416289615795 Altitude: 51.84394 HWP Angle: 0.0 IMR Angle: 90.43947
# Parallactic Angle: 19.84086187943678 Altitude: 51.76075 HWP Angle: 45.0 IMR Angle: 90.39709
# Parallactic Angle: 20.22159365848962 Altitude: 51.67382 HWP Angle: 22.5 IMR Angle: 90.35546
# Parallactic Angle: 20.61262248335183 Altitude: 51.58403 HWP Angle: 67.5 IMR Angle: 90.30941
# Parallactic Angle: 21.00149751336854 Altitude: 51.49033 HWP Angle: 0.0 IMR Angle: 90.26312
# Parallactic Angle: 21.37996334358739 Altitude: 51.39908 HWP Angle: 45.0 IMR Angle: 90.21549
# Parallactic Angle: 21.75102050907535 Altitude: 51.30685 HWP Angle: 22.5 IMR Angle: 90.17117
# Parallactic Angle: 22.13443682579749 Altitude: 51.20937 HWP Angle: 67.5 IMR Angle: 90.12381
# Parallactic Angle: 22.51313929927433 Altitude: 51.11099 HWP Angle: 0.0 IMR Angle: 90.07248
# Parallactic Angle: 22.88142541271298 Altitude: 51.01318 HWP Angle: 45.0 IMR Angle: 90.02678
# Parallactic Angle: 23.25070098827623 Altitude: 50.91336 HWP Angle: 22.5 IMR Angle: 89.97625
# Parallactic Angle: 23.62371628098047 Altitude: 50.81011 HWP Angle: 67.5 IMR Angle: 89.92295
# Parallactic Angle: 23.99772213221643 Altitude: 50.70481 HWP Angle: 0.0 IMR Angle: 89.86628
# Parallactic Angle: 24.35825756709455 Altitude: 50.60071 HWP Angle: 45.0 IMR Angle: 89.80939
# Parallactic Angle: 24.71984105405398 Altitude: 50.49478 HWP Angle: 22.5 IMR Angle: 89.75006
# Parallactic Angle: 25.08241668978282 Altitude: 50.38554 HWP Angle: 67.5 IMR Angle: 89.69869
# Parallactic Angle: 25.4513173950003 Altitude: 50.27391 HWP Angle: 0.0 IMR Angle: 89.6465
# Parallactic Angle: 25.80421968946893 Altitude: 50.16405 HWP Angle: 45.0 IMR Angle: 89.58813
# Parallactic Angle: 26.15252704074693 Altitude: 50.05345 HWP Angle: 22.5 IMR Angle: 89.54357
# Parallactic Angle: 26.51515216040749 Altitude: 49.93154 HWP Angle: 67.5 IMR Angle: 89.47716
# Parallactic Angle: 26.87060847164013 Altitude: 49.81981 HWP Angle: 0.0 IMR Angle: 89.42801
# Parallactic Angle: 27.21563415878568 Altitude: 49.70459 HWP Angle: 45.0 IMR Angle: 89.35687
# Parallactic Angle: 27.55872654412761 Altitude: 49.58816 HWP Angle: 22.5 IMR Angle: 89.30036
# Parallactic Angle: 27.91057568375006 Altitude: 49.46648 HWP Angle: 67.5 IMR Angle: 89.23989
# Parallactic Angle: 28.26037434399979 Altitude: 49.34298 HWP Angle: 0.0 IMR Angle: 89.18835
# Parallactic Angle: 28.59766689999248 Altitude: 49.22167 HWP Angle: 45.0 IMR Angle: 89.11749
# Parallactic Angle: 28.93270546482297 Altitude: 49.09979 HWP Angle: 22.5 IMR Angle: 89.06602
# Parallactic Angle: 29.27367846947032 Altitude: 48.9733 HWP Angle: 67.5 IMR Angle: 88.98643
# Parallactic Angle: 29.61523820093363 Altitude: 48.84407 HWP Angle: 0.0 IMR Angle: 88.93586
# Parallactic Angle: 29.94871147195061 Altitude: 48.71765 HWP Angle: 45.0 IMR Angle: 88.86831
# Parallactic Angle: 30.27592586949896 Altitude: 48.5897 HWP Angle: 22.5 IMR Angle: 88.80783
# Parallactic Angle: 30.60841131204293 Altitude: 48.45825 HWP Angle: 67.5 IMR Angle: 88.74259
# Parallactic Angle: 30.94162293306445 Altitude: 48.32326 HWP Angle: 0.0 IMR Angle: 88.68091
# Parallactic Angle: 31.26280677282874 Altitude: 48.19165 HWP Angle: 45.0 IMR Angle: 88.61115
# Parallactic Angle: 31.58205826163368 Altitude: 48.05964 HWP Angle: 22.5 IMR Angle: 88.54647
# Parallactic Angle: 31.90639807793384 Altitude: 47.92201 HWP Angle: 67.5 IMR Angle: 88.4786
# Parallactic Angle: 32.23127622553576 Altitude: 47.78268 HWP Angle: 0.0 IMR Angle: 88.40784
# Parallactic Angle: 32.54683860902431 Altitude: 47.6455 HWP Angle: 45.0 IMR Angle: 88.34067
# Parallactic Angle: 32.85549106775499 Altitude: 47.50669 HWP Angle: 22.5 IMR Angle: 88.26774
# Parallactic Angle: 33.17427806412488 Altitude: 47.36645 HWP Angle: 67.5 IMR Angle: 88.19808
# Parallactic Angle: 33.49094256815182 Altitude: 47.22219 HWP Angle: 0.0 IMR Angle: 88.13371
# Parallactic Angle: 33.79595324062613 Altitude: 47.08134 HWP Angle: 45.0 IMR Angle: 88.05956
# Parallactic Angle: 34.09911050541308 Altitude: 46.93869 HWP Angle: 22.5 IMR Angle: 87.97696
# Parallactic Angle: 34.40961844055446 Altitude: 46.79131 HWP Angle: 67.5 IMR Angle: 87.90951
# Parallactic Angle: 34.71816815027012 Altitude: 46.6425 HWP Angle: 0.0 IMR Angle: 87.83409
# Parallactic Angle: 35.0152118844091 Altitude: 46.49688 HWP Angle: 45.0 IMR Angle: 87.7498
# Parallactic Angle: 35.31020432388596 Altitude: 46.34968 HWP Angle: 22.5 IMR Angle: 87.6884
# Parallactic Angle: 35.61266739895788 Altitude: 46.19771 HWP Angle: 67.5 IMR Angle: 87.61501
# Parallactic Angle: 35.91303513020456 Altitude: 46.04412 HWP Angle: 0.0 IMR Angle: 87.53569
# Parallactic Angle: 36.20002831930627 Altitude: 45.89483 HWP Angle: 45.0 IMR Angle: 87.46655
# Parallactic Angle: 36.48724942901845 Altitude: 45.74378 HWP Angle: 22.5 IMR Angle: 87.38209
# Parallactic Angle: 36.78166587653178 Altitude: 45.58691 HWP Angle: 67.5 IMR Angle: 87.29227
# Parallactic Angle: 37.07606059707799 Altitude: 45.428 HWP Angle: 0.0 IMR Angle: 87.2329
# Parallactic Angle: 37.35333315355535 Altitude: 45.27524 HWP Angle: 45.0 IMR Angle: 87.15044
# Parallactic Angle: 37.63511735753644 Altitude: 45.11955 HWP Angle: 22.5 IMR Angle: 87.06957
# Parallactic Angle: 37.91927400567582 Altitude: 44.95918 HWP Angle: 67.5 IMR Angle: 86.97858
# Parallactic Angle: 38.20378162389563 Altitude: 44.79654 HWP Angle: 0.0 IMR Angle: 86.91396
# Parallactic Angle: 38.47976975510051 Altitude: 44.63633 HWP Angle: 45.0 IMR Angle: 86.82677
# Parallactic Angle: 38.7519061652817 Altitude: 44.47886 HWP Angle: 22.5 IMR Angle: 86.74141
# Parallactic Angle: 39.02819277556394 Altitude: 44.31595 HWP Angle: 67.5 IMR Angle: 86.67714
# Parallactic Angle: 39.30483844088381 Altitude: 44.14802 HWP Angle: 0.0 IMR Angle: 86.58446
# Parallactic Angle: 39.57139710073275 Altitude: 43.98594 HWP Angle: 45.0 IMR Angle: 86.50413
# Parallactic Angle: 39.83579786521059 Altitude: 43.8237 HWP Angle: 22.5 IMR Angle: 86.43258
# Parallactic Angle: 40.10684451123674 Altitude: 43.65386 HWP Angle: 67.5 IMR Angle: 86.34511
# Parallactic Angle: 40.37593622615697 Altitude: 43.48592 HWP Angle: 0.0 IMR Angle: 86.25913
# Parallactic Angle: 40.6348784230433 Altitude: 43.31909 HWP Angle: 45.0 IMR Angle: 86.17663
# Parallactic Angle: 40.89022770723824 Altitude: 43.15321 HWP Angle: 22.5 IMR Angle: 86.09555
# Parallactic Angle: 41.1537230081499 Altitude: 42.98096 HWP Angle: 67.5 IMR Angle: 86.00991
# Parallactic Angle: 41.41536012298005 Altitude: 42.80779 HWP Angle: 0.0 IMR Angle: 85.91368
# Parallactic Angle: 41.66715961004004 Altitude: 42.63796 HWP Angle: 45.0 IMR Angle: 85.83553
# Parallactic Angle: 41.9153837674172 Altitude: 42.4686 HWP Angle: 22.5 IMR Angle: 85.74309
# Parallactic Angle: 42.17158616395373 Altitude: 42.29145 HWP Angle: 67.5 IMR Angle: 85.66488
# Parallactic Angle: 42.42594270295903 Altitude: 42.1142 HWP Angle: 0.0 IMR Angle: 85.57299
# Parallactic Angle: 42.67277892784699 Altitude: 41.94123 HWP Angle: 45.0 IMR Angle: 85.47562
# Parallactic Angle: 42.91406519913403 Altitude: 41.76855 HWP Angle: 22.5 IMR Angle: 85.39823
# Parallactic Angle: 43.16491162748594 Altitude: 41.58823 HWP Angle: 67.5 IMR Angle: 85.30134
# Parallactic Angle: -54.00396403346271 Altitude: 30.49336 HWP Angle: 0.0 IMR Angle: 79.74685
# Parallactic Angle: -53.61284172342158 Altitude: 30.97838 HWP Angle: 45.0 IMR Angle: 79.99572
# Parallactic Angle: -53.44155119395407 Altitude: 31.18647 HWP Angle: 22.5 IMR Angle: 80.10656
# Parallactic Angle: -53.26894206826127 Altitude: 31.39673 HWP Angle: 67.5 IMR Angle: 80.1983
# Parallactic Angle: -53.09117072311773 Altitude: 31.61003 HWP Angle: 0.0 IMR Angle: 80.30669
# Parallactic Angle: -52.92043666797988 Altitude: 31.81353 HWP Angle: 45.0 IMR Angle: 80.40883
# Parallactic Angle: -52.74705869811152 Altitude: 32.01723 HWP Angle: 22.5 IMR Angle: 80.5102
# Parallactic Angle: -52.56714286577554 Altitude: 32.2278 HWP Angle: 67.5 IMR Angle: 80.6159
# Parallactic Angle: -52.30852949719571 Altitude: 32.53173 HWP Angle: 0.0 IMR Angle: 80.76132
# Parallactic Angle: -52.02531621056816 Altitude: 32.85324 HWP Angle: 45.0 IMR Angle: 80.92445
# Parallactic Angle: -51.84587649179795 Altitude: 33.05543 HWP Angle: 22.5 IMR Angle: 81.02365
# Parallactic Angle: -51.65958098559713 Altitude: 33.26312 HWP Angle: 67.5 IMR Angle: 81.1359
# Parallactic Angle: -35.20173532222326 Altitude: 45.83101 HWP Angle: 0.0 IMR Angle: 87.41067
# Parallactic Angle: -34.39513071095625 Altitude: 46.23359 HWP Angle: 45.0 IMR Angle: 87.61494
# Parallactic Angle: -34.09594501229384 Altitude: 46.3767 HWP Angle: 22.5 IMR Angle: 87.68598
# Parallactic Angle: -33.78500777166076 Altitude: 46.52454 HWP Angle: 67.5 IMR Angle: 87.75532
# Parallactic Angle: -32.94625640470807 Altitude: 46.91421 HWP Angle: 0.0 IMR Angle: 87.95691
# Parallactic Angle: -32.0631565867586 Altitude: 47.30649 HWP Angle: 45.0 IMR Angle: 88.14896
# Parallactic Angle: -31.75400822719742 Altitude: 47.43974 HWP Angle: 22.5 IMR Angle: 88.21883
# Parallactic Angle: -31.42795358558021 Altitude: 47.57961 HWP Angle: 67.5 IMR Angle: 88.2909
# Parallactic Angle: 3.052342205695818 Altitude: 53.49314 HWP Angle: 0.0 IMR Angle: 91.2398
# Parallactic Angle: 4.198682137115489 Altitude: 53.45304 HWP Angle: 45.0 IMR Angle: 91.23545
# Parallactic Angle: 4.617583962785923 Altitude: 53.43494 HWP Angle: 22.5 IMR Angle: 91.23438
# Parallactic Angle: 5.052422134130619 Altitude: 53.41399 HWP Angle: 67.5 IMR Angle: 91.22457
# Parallactic Angle: 5.4868647430856 Altitude: 53.39148 HWP Angle: 0.0 IMR Angle: 91.21087
# Parallactic Angle: 5.907284862613547 Altitude: 53.36725 HWP Angle: 45.0 IMR Angle: 91.19465
# Parallactic Angle: 6.327385482101193 Altitude: 53.34155 HWP Angle: 22.5 IMR Angle: 91.18447
# Parallactic Angle: 6.759888954100684 Altitude: 53.31294 HWP Angle: 67.5 IMR Angle: 91.1766

# %% [markdown]
# # Plotting Forward Model

# %%
# Extract altitudes, Q_data, and U_data from the previous block of code
altitudes = [item[0] for item in Q_list]  # Extracting altitudes from Q_list (they are the same for U_list)
Q_data = np.array([item[1] for item in Q_list]).flatten()
U_data = np.array([item[1] for item in U_list]).flatten()

# Initial guesses for delta_m3, epsilon_m3, and offset
initial_guesses = [0, 0.01, 1]
bounds = [(0, 1), (-0.5, 0.5), (-10, 10)]

# Perform the minimization using Nelder-Mead with bounds
result = minimize(m3.residuals, initial_guesses, args=(altitudes, Q_data, U_data), method='Nelder-Mead', bounds=bounds)

# Extract the best-fit parameters
delta_m3_best, epsilon_m3_best, offset_best = result.x

print("Best Fit M3 Diattenuation: " + str(epsilon_m3_best))
print("Best Fit Offset: " + str(offset_best))

# Calculate the fitted Q and U values
# Q_fitted, U_fitted = m3.propagate_unpol_source(delta_m3_best, epsilon_m3_best, offset_best, altitudes)
Q_fitted, U_fitted = m3.propagate_unpol_source(0, 0.0176, -2.5, altitudes)

# Sort the fitted values by altitude
sorted_indices = np.argsort(altitudes)
altitudes_sorted = np.array(altitudes)[sorted_indices]
Q_fitted_sorted = Q_fitted[sorted_indices]
U_fitted_sorted = U_fitted[sorted_indices]

# Plotting the data and the fitted line
plt.figure(figsize=(12, 8))
plotted_labels = set()
for (altitude, Q, color, obj), Q_err in zip(Q_list, Q_err_list):
    label = f'Q - {obj}' if f'Q - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, Q, yerr=Q_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor=color)
    plotted_labels.add(f'Q - {obj}')

for (altitude, U, color, obj), U_err in zip(U_list, U_err_list):
    label = f'U - {obj}' if f'U - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, U, yerr=U_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor='none', markeredgecolor=color)
    plotted_labels.add(f'U - {obj}')

# Plot the fitted line with different colors for Q and U
plt.plot(altitudes_sorted, Q_fitted_sorted, label='Fitted Q', linestyle='-', color='blue')
plt.plot(altitudes_sorted, U_fitted_sorted, label='Fitted U', linestyle='-', color='red')

plt.title(f"Stokes Q and U of {wavelength}nm Eta Crv Data @ HWP - EM Gain Ratio = " + str(em_gain))
plt.xlabel("Altitude (Degrees)")
plt.ylabel("Stokes Parameter")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Best Fit M3 Diattenuation: 0.5
# Best Fit Offset: -10.0

# %% [markdown]
# # Matrix Inversion for On-Sky Frame of Reference

# %%
# Internal Calibration Model Parameters from MCMC best fit value - 
# https://docs.google.com/spreadsheets/d/1i8TjHzQFMmxaUWrrqm1eYziyUanC6pweGGFzJPdfbiE/edit#gid=0

delta_m3 = 0.5 # (waves) - assumed to be zero for now
epsilon_m3 = 0.01244  # Rough value from unpolarized standards fit
offset_m3 = -2.5  # NOTE: Made this zero too for testing purposes
em_gain = 0.423  # Add your actual em_gain value
delta_HWP = 0.451  # Add your actual delta_HWP value
offset_HWP = -2.642  # Add your actual offset_HWP value
delta_derot = 0.32  # Add your actual delta_derot value
offset_derot = -0.011  # Add your actual offset_derot value
delta_opts = -0.163  # Add your actual delta_opts value
epsilon_opts = 0.036  # Add your actual epsilon_opts value
rot_opts = -7.151  # Add your actual rot_opts value
delta_FLC = 0.302  # Add your actual delta_FLC value
rot_FLC = 0.256  # Add your actual rot_FLC value

# For changing certain parameters
# delta_FLC = 0.5
# em_gain = 1 / 1.08
# epsilon_opts = 0 # Made this zero for testing purposes

# For figuring out the correrct factor for the double diff matrix
double_diff_factor = 1

fixed_params = [delta_m3, epsilon_m3, offset_m3, delta_HWP, offset_HWP, 
    delta_derot, offset_derot, delta_opts, epsilon_opts, rot_opts, delta_FLC, 
    rot_FLC, em_gain]

# %%
# Extract unique objects and generate colors
unique_objects = all_data['OBJECT'].unique()
colors = itertools.cycle(plt.cm.tab10.colors)  # Use a colormap with a cycle of 10 colors

# Initialize lists for storing the results
wavelength = 675
Q_list = []
U_list = []
Q_err_list = []
U_err_list = []
final_altitudes = []

model = matrices.full_system_mueller_matrix

# Loop through each unique object
for obj in unique_objects:
    object_data = all_data[all_data['OBJECT'] == obj]
    color = next(colors)

    # Initialize lists for this object
    first_rows = []
    inst_matrices_at_HWP = []
    this_cycle_intensities = []
    this_cycle_altitudes = []
    this_cycle_errors = []

    for i, row in object_data.iterrows():
        HWP_ang = row["U_HWPANG"]
        IMR_ang = row["D_IMRANG"]
        cam_num = row["U_CAMERA"]
        FLC_state = row["U_FLCSTT"]
        altitude = row["ALTITUDE"]
        parang = row["PA"]
        data_Q = row["Q"]

        # NOTE: This is for normalized differences
        double_difference = row[double_diff_string]
        # double_sum = row["DOUBLE_SUM"]
        double_difference_err = row["DOUBLE_DIFFERENCE_ERRS"]

        if double_difference != 0:
            # Append intensities and altitudes for this cycle
            this_cycle_intensities.append(double_difference)
            this_cycle_altitudes.append(altitude)
            this_cycle_errors.append(double_difference_err)

            # Calculate instrument matrix at HWP
            these_inst_matrices_at_HWP = matrices.full_system_mueller_matrix_normalized_double_diff_and_sum(
                model, fixed_params, parang, altitude, HWP_ang, IMR_ang, factor = double_diff_factor)
            double_diff_matrix_at_HWP = these_inst_matrices_at_HWP[0]
            double_sum_matrix_at_HWP = these_inst_matrices_at_HWP[1]

            # Setting the I component to be 1
            # double_diff_matrix_at_HWP[0, 0] = 1

            # Saving instrument matrices
            inst_matrices_at_HWP.append(double_diff_matrix_at_HWP)
            inst_matrices_at_HWP.append(double_sum_matrix_at_HWP)

            # Take only the first row and I, Q, U, components (no V)
            first_rows.append(double_diff_matrix_at_HWP[0, : 3])  

        # Do one inversion for one HWP cycle
        if data_Q != 0:
            # Constructing measurement matrix to reconstruct Stokes vector at HWP
            measurement_matrix = np.vstack(first_rows)
            measurements = np.array(this_cycle_intensities).reshape(-1, 1)  # Reshape total counts to a column vector
            errors = np.array(this_cycle_errors).reshape(-1, 1)  # Reshape errors to a column vector

            # Compute the pseudo-inverse of the measurement matrix and multiply it by the measurements vector
            s_HWP = np.linalg.pinv(measurement_matrix) @ measurements

            # Compute the errors for the Stokes parameters
            s_HWP_err = np.linalg.pinv(measurement_matrix) @ errors

            # Extract Q and U from s_HWP and their errors
            Q = s_HWP[1]
            U = s_HWP[2]
            Q_err = s_HWP_err[1]
            U_err = s_HWP_err[2]

            # Append Q, U, altitude, and errors to the lists
            Q_list.append((altitude, Q, color, obj))
            U_list.append((altitude, U, color, obj))
            Q_err_list.append(Q_err)
            U_err_list.append(U_err)

            # Saving the mean of the altitudes
            mean_altitude = np.mean(this_cycle_altitudes)

            # Reset measurement matrix rows and double diff and sum measurements
            first_rows = []  
            this_cycle_intensities = []
            this_cycle_altitudes = []
            this_cycle_errors = []

            final_altitudes.append(mean_altitude)

# TODO: See if it's ok to just take the absolute uncertainties
Q_err_list = np.abs(Q_err_list)
U_err_list = np.abs(U_err_list)

# Plotting
plt.figure(figsize=(12, 8))
plotted_labels = set()
for (altitude, Q, color, obj), Q_err in zip(Q_list, Q_err_list):
    label = f'Q - {obj}' if f'Q - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, Q, yerr=Q_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor=color)
    plotted_labels.add(f'Q - {obj}')

for (altitude, U, color, obj), U_err in zip(U_list, U_err_list):
    label = f'U - {obj}' if f'U - {obj}' not in plotted_labels else None
    plt.errorbar(altitude, U, yerr=U_err, label=label, linestyle='None', marker='o', color=color, markerfacecolor='none', markeredgecolor=color)
    plotted_labels.add(f'U - {obj}')

plt.title(f"Stokes Q and U of {wavelength}nm Eta Crv Data @ HWP - EM Gain Ratio = " + str(em_gain))
plt.xlabel("Altitude (Degrees)")
plt.ylabel("Stokes (Q/U)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()
